# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
c_5=df.iloc[:,4]
c_5.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %%
c=df[(df['gender']=="Male") & (df['SeniorCitizen']==1 )&(df['PaymentMethod']=='Electronic check')]
c.head()
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV   Male              1      No         No       1           No
# 55  1658-BYGOY   Male              1      No         No      18          Yes
# 57  5067-XJQFU   Male              1     Yes        Yes      66          Yes
# 78  0191-ZHSKZ   Male              1      No         No      30          Yes
# 91  2424-WVHPL   Male              1      No         No       1          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 55               Yes     Fiber optic             No  ...               No
# 57               Yes     Fiber optic             No  ...              Yes
# 78                No             DSL            Yes  ...               No
# 91                No     Fiber optic             No  ...               No
#
# ...

# %%
g=df[(df['tenure']>70)|(df['MonthlyCharges']>100)]
g.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %%
g1=df[(df['Contract']=="Two year")&(df['PaymentMethod']=="Mailed check")&(df[ 'Churn']=="Yes")]
g1.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
# Random Sampling
c333=df.sample(n=333)
c333.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4521  8671-KKKOS  Female              0     Yes         No      46
# 4394  0228-MAUWC    Male              0      No         No      19
# 6450  4609-KNNWG  Female              0     Yes        Yes      27
# 3176  5044-XDPYX  Female              0     Yes         No      51
# 5002  0567-XRHCU  Female              0     Yes        Yes      69
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 4521           No  No phone service             DSL                  Yes  ...
# 4394          Yes               Yes             DSL                   No  ...
# 6450          Yes                No              No  No internet service  ...
# 3176          Yes               Yes              No  No internet service  ...
# 5002           No  No phone service             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
# data visualizzation
x1=df['InternetService'].value_counts().keys().tolist()
y1=df['InternetService'].value_counts().tolist()
plt.bar(x1,y1,color="orange")
plt.xlabel("Categories of Internet Service")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['tenure'],bins=30,color="green")
plt.title("distribution of Tenure")
# Out:
# Text(0.5, 1.0, 'distribution of Tenure')

# %%
# distribution of categorical values go for bar 
# distribution of continuous value go gor histogram

# %%
plt.scatter(x=df['tenure'],y=df['MonthlyCharges'])
plt.title('montly charges vs tenure')
plt.show()

# %%
df.boxplot(column=['tenure'],by=['Contract'])
# Out:
# <Axes: title={'center': 'tenure'}, xlabel='[Contract]'>

# %%
# Machine Learning
# linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
y=df[['MonthlyCharges']]
x=df[['tenure']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 29.394584027273893

# %%
# new model for Logistic Regression
x=df[['MonthlyCharges']]
y=df[['Churn']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# E:\Anaconda_instalation\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score

# %%
confusion_matrix(y_test,y_pred),accuracy_score(y_test,y_pred)
# Out:
# (array([[1815,    0],
#         [ 651,    0]], dtype=int64),
#  0.7360097323600974)

# %%
# new model for Decision Tree Regression
x=df[['tenure']]
y=df[['Churn']]

# %%
from sklearn.tree  import DecisionTreeClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
confusion_matrix(y_test,y_pred),accuracy_score(y_test,y_pred)
# Out:
# (array([[965,  76],
#         [281,  87]], dtype=int64),
#  0.7466288147622427)

# %%
# random Forest
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
confusion_matrix(y_test,y_pred),accuracy_score(y_test,y_pred)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3080\3960040368.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train,y_train)
# (array([[965,  76],
#         [281,  87]], dtype=int64),
#  0.7466288147622427)
